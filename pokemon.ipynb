# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
df=pd.read_csv('Pokemon.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df=df.drop('#',axis=1)
df.head()
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0              Bulbasaur  Grass  Poison    318  45      49       49       65
# 1                Ivysaur  Grass  Poison    405  60      62       63       80
# 2               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# 4             Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        800 non-null    object
#  1   Type 1      800 non-null    object
#  2   Type 2      414 non-null    object
#  3   Total       800 non-null    int64
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
df.isnull().sum()
# Out:
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
df["Type 2"]=df["Type 2"].fillna("No Type")

# %%
df.head()
# Out:
#                     Name Type 1   Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0              Bulbasaur  Grass   Poison    318  45      49       49       65
# 1                Ivysaur  Grass   Poison    405  60      62       63       80
# 2               Venusaur  Grass   Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass   Poison    625  80     100      123      122
# 4             Charmander   Fire  No Type    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        800 non-null    object
#  1   Type 1      800 non-null    object
#  2   Type 2      800 non-null    object
#  3   Total       800 non-null    int64
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
df['Type 1'].value_counts()
# Out:
# Type 1
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Rock         44
# Electric     44
# Ground       32
# Ghost        32
# Dragon       32
# Dark         31
# Poison       28
# Fighting     27
# Steel        27
# Ice          24
# Fairy        17
# Flying        4
# Name: count, dtype: int64

# %%
df['Type 2'].value_counts()
# Out:
# Type 2
# No Type     386
# Flying       97
# Ground       35
# Poison       34
# Psychic      33
# Fighting     26
# Grass        25
# Fairy        23
# Steel        22
# Dark         20
# Dragon       18
# Ice          14
# Rock         14
# Water        14
# Ghost        14
# Fire         12
# Electric      6
# Normal        4
# Bug           3
# Name: count, dtype: int64

# %%
df.head()
# Out:
#                     Name Type 1   Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0              Bulbasaur  Grass   Poison    318  45      49       49       65
# 1                Ivysaur  Grass   Poison    405  60      62       63       80
# 2               Venusaur  Grass   Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass   Poison    625  80     100      123      122
# 4             Charmander   Fire  No Type    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df['Total_Attack']=df['Attack']+df['Sp. Atk']
df
# Out:
#                       Name   Type 1   Type 2  Total  HP  Attack  Defense  \
# 0                Bulbasaur    Grass   Poison    318  45      49       49
# 1                  Ivysaur    Grass   Poison    405  60      62       63
# 2                 Venusaur    Grass   Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass   Poison    625  80     100      123
# 4               Charmander     Fire  No Type    309  39      52       43
# ..                     ...      ...      ...    ...  ..     ...      ...
# 795                Diancie     Rock    Fairy    600  50     100      150
# 796    DiancieMega Diancie     Rock    Fairy    700  50     160      110
# 797    HoopaHoopa Confined  Psychic    Ghost    600  80     110       60
# 798     HoopaHoopa Unbound  Psychic     Dark    680  80     160       60
# 799              Volcanion     Fire    Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total_Attack
# ...

# %%
df.drop_duplicates()
# Out:
#                       Name   Type 1   Type 2  Total  HP  Attack  Defense  \
# 0                Bulbasaur    Grass   Poison    318  45      49       49
# 1                  Ivysaur    Grass   Poison    405  60      62       63
# 2                 Venusaur    Grass   Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass   Poison    625  80     100      123
# 4               Charmander     Fire  No Type    309  39      52       43
# ..                     ...      ...      ...    ...  ..     ...      ...
# 795                Diancie     Rock    Fairy    600  50     100      150
# 796    DiancieMega Diancie     Rock    Fairy    700  50     160      110
# 797    HoopaHoopa Confined  Psychic    Ghost    600  80     110       60
# 798     HoopaHoopa Unbound  Psychic     Dark    680  80     160       60
# 799              Volcanion     Fire    Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total_Attack
# ...

# %%
#df.drop(columns=['Legendary'],inplace=True)
df
# Out:
#                       Name   Type 1   Type 2  Total  HP  Attack  Defense  \
# 0                Bulbasaur    Grass   Poison    318  45      49       49
# 1                  Ivysaur    Grass   Poison    405  60      62       63
# 2                 Venusaur    Grass   Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass   Poison    625  80     100      123
# 4               Charmander     Fire  No Type    309  39      52       43
# ..                     ...      ...      ...    ...  ..     ...      ...
# 795                Diancie     Rock    Fairy    600  50     100      150
# 796    DiancieMega Diancie     Rock    Fairy    700  50     160      110
# 797    HoopaHoopa Confined  Psychic    Ghost    600  80     110       60
# 798     HoopaHoopa Unbound  Psychic     Dark    680  80     160       60
# 799              Volcanion     Fire    Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total_Attack
# ...

# %%
df['Total_defense']=df['Defense']+df['Sp. Def']
df
# Out:
#                       Name   Type 1   Type 2  Total  HP  Attack  Defense  \
# 0                Bulbasaur    Grass   Poison    318  45      49       49
# 1                  Ivysaur    Grass   Poison    405  60      62       63
# 2                 Venusaur    Grass   Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass   Poison    625  80     100      123
# 4               Charmander     Fire  No Type    309  39      52       43
# ..                     ...      ...      ...    ...  ..     ...      ...
# 795                Diancie     Rock    Fairy    600  50     100      150
# 796    DiancieMega Diancie     Rock    Fairy    700  50     160      110
# 797    HoopaHoopa Confined  Psychic    Ghost    600  80     110       60
# 798     HoopaHoopa Unbound  Psychic     Dark    680  80     160       60
# 799              Volcanion     Fire    Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total_Attack  \
# ...

# %%
df['Battle_Score']=df['Attack']+df['Defense']+df['Speed']

# %%
df
# Out:
#                       Name   Type 1   Type 2  Total  HP  Attack  Defense  \
# 0                Bulbasaur    Grass   Poison    318  45      49       49
# 1                  Ivysaur    Grass   Poison    405  60      62       63
# 2                 Venusaur    Grass   Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass   Poison    625  80     100      123
# 4               Charmander     Fire  No Type    309  39      52       43
# ..                     ...      ...      ...    ...  ..     ...      ...
# 795                Diancie     Rock    Fairy    600  50     100      150
# 796    DiancieMega Diancie     Rock    Fairy    700  50     160      110
# 797    HoopaHoopa Confined  Psychic    Ghost    600  80     110       60
# 798     HoopaHoopa Unbound  Psychic     Dark    680  80     160       60
# 799              Volcanion     Fire    Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total_Attack  \
# ...

# %%
df.count()
# Out:
# Name             800
# Type 1           800
# Type 2           800
# Total            800
# HP               800
# Attack           800
# Defense          800
# Sp. Atk          800
# Sp. Def          800
# Speed            800
# Generation       800
# Legendary        800
# Total_Attack     800
# Total_defense    800
# Battle_Score     800
# dtype: int64

# %%
#10 strongest pokemons
df.nlargest(10,'Total')
# Out:
#                         Name   Type 1    Type 2  Total   HP  Attack  Defense  \
# 163      MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190      100
# 164      MewtwoMega Mewtwo Y  Psychic   No Type    780  106     150       70
# 426    RayquazaMega Rayquaza   Dragon    Flying    780  105     180      100
# 422      KyogrePrimal Kyogre    Water   No Type    770  100     150       90
# 424    GroudonPrimal Groudon   Ground      Fire    770  100     180      160
# 552                   Arceus   Normal   No Type    720  120     120      120
# 268  TyranitarMega Tyranitar     Rock      Dark    700  100     164      150
# 409  SalamenceMega Salamence   Dragon    Flying    700   95     145      130
# 413  MetagrossMega Metagross    Steel   Psychic    700   80     145      150
# 418        LatiasMega Latias   Dragon   Psychic    700   80     100      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total_Attack  \
# ...

# %%
df.nsmallest(10,'Total')
# Out:
#            Name   Type 1   Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 206     Sunkern    Grass  No Type    180  30      30       30       30
# 322     Azurill   Normal    Fairy    190  50      20       40       20
# 446   Kricketot      Bug  No Type    194  37      25       41       25
# 13     Caterpie      Bug  No Type    195  45      30       35       20
# 16       Weedle      Bug   Poison    195  40      35       30       20
# 288     Wurmple      Bug  No Type    195  45      45       35       20
# 303       Ralts  Psychic    Fairy    198  28      25       25       45
# 139    Magikarp    Water  No Type    200  20      10       55       15
# 381      Feebas    Water  No Type    200  20      15       20       10
# 732  Scatterbug      Bug  No Type    200  38      35       40       27
#
#      Sp. Def  Speed  Generation  Legendary  Total_Attack  Total_defense  \
# 206       30     30           2      False            60             60
# ...

# %%
countoftype1=df['Type 1'].value_counts()
countoftype1
# Out:
# Type 1
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Rock         44
# Electric     44
# Ground       32
# Ghost        32
# Dragon       32
# Dark         31
# Poison       28
# Fighting     27
# Steel        27
# Ice          24
# Fairy        17
# Flying        4
# Name: count, dtype: int64

# %%
countoftype1.plot(kind='bar',color='orange')
plt.title('Count of Pokemons by Type 1')
plt.xlabel('Type1')
# Out:
# Text(0.5, 0, 'Type1')

# %%
countoftype2=df['Type 2'].value_counts()
countoftype2
# Out:
# Type 2
# No Type     386
# Flying       97
# Ground       35
# Poison       34
# Psychic      33
# Fighting     26
# Grass        25
# Fairy        23
# Steel        22
# Dark         20
# Dragon       18
# Ice          14
# Rock         14
# Water        14
# Ghost        14
# Fire         12
# Electric      6
# Normal        4
# Bug           3
# Name: count, dtype: int64

# %%
countoftype2.plot(kind='bar',color='Red')
plt.title('Count of Pokemons by Type 2')
plt.xlabel('Type2')
# Out:
# Text(0.5, 0, 'Type2')

# %%
plt.hist(df['Total_Attack'],bins=15,color='Red')
# Out:
# (array([  8.,  19.,  49., 122., 110., 145., 115., 112.,  41.,  33.,  25.,
#          10.,   3.,   4.,   4.]),
#  array([ 20.        ,  42.66666667,  65.33333333,  88.        ,
#         110.66666667, 133.33333333, 156.        , 178.66666667,
#         201.33333333, 224.        , 246.66666667, 269.33333333,
#         292.        , 314.66666667, 337.33333333, 360.        ]),
#  <BarContainer object of 15 artists>)

# %%
plt.scatter(df['Total_Attack'],df['Total_defense'])

# %%
legendary = df["Legendary"].value_counts()
legendary
# Out:
# Legendary
# False    735
# True      65
# Name: count, dtype: int64

# %%
legendary.plot(kind='pie',labels=['Non Legendary','Legendary'],colors=['orange','Red'])
# Out:
# <Axes: ylabel='count'>

# %%
top10=df.nlargest(10,'Total_Attack')[['Name','Total_Attack']].set_index('Name')
top10.plot(kind='barh')
# Out:
# <Axes: ylabel='Name'>
